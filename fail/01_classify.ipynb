# %% [markdown]
# # Classify
# * Load the feature matrix prepared in previous notebook
# * Split the data into train/validate/test datasets
# * Compute a baseline
# * Classify using Support Vector Machine

# %%
import numpy as np
from os.path import join
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import pandas as pd
import random

# %% [markdown]
# Load the feature matrix prepared in previous notebook

# %%
DATA_PATH = 'data'

with np.load(join(DATA_PATH, 'processed_data.npz')) as data:
    data_dict=dict(data.items())
X = data_dict['X']
y = data_dict['y']

# %% [markdown]
# Split the data into train/validate/test datasets

# %%
# Split the data into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=0)
print('The training dataset has {} entries, the test dataset {}.'.format(
    len(X_train), len(X_test)))
# Out:
# The training dataset has 11532 entries, the test dataset 3844.

# %% [markdown]
# ## Compute a baseline

# %%
# Create the dummy classifier
dummy = DummyClassifier(strategy='most_frequent')

# Fit it to the train data
dummy.fit(X_train, y_train)

# Compute accuracy on the test set
accuracy = dummy.score(X_test, y_test)
print('Baseline accuracy: {:.3f}'.format(accuracy))
# Out:
# Baseline accuracy: 0.155

# %% [markdown]
# ## SVM
# Create a pipeline using a standard scaler and a support vector machine (SVM) model.

# %%
# Create SVM
svc = SVC(kernel='rbf', C=1, gamma='scale')

pipe_svc = Pipeline([
    ('scaler', StandardScaler()), # More accurate with standardization?
    #('scaler', None), # Better performance (faster) without standardization?
    ('svc', svc)
])

# %% [markdown]
# ### Tune the SVM model
# Tune C (regularization) parameter (skipped gamma set to 'scale' by default), using grid search

# %%
# %%time
# Create cross-validation object
grid_svc = {
    'svc__C': [0.75, 1, 2.5, 5, 7.5, 10],
}
# create grid search with cross validation
gridsearch_svc = GridSearchCV(pipe_svc, grid_svc, cv=4, return_train_score=True, verbose=3, n_jobs=4)

# Get a smaller random sample for tuning the parameter
NUM_SAMPLES = 1000
idx = random.sample(range(len(X_train)-1), NUM_SAMPLES)
X_rnd = X_train[idx]
y_rnd = y_train[idx]

# Fit estimator
gridsearch_svc.fit(X_rnd, y_rnd)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# CPU times: user 1min 45s, sys: 391 ms, total: 1min 45s
# Wall time: 5min 11s
# GridSearchCV(cv=4,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svc', SVC(C=1))]),
#              n_jobs=4, param_grid={'svc__C': [0.75, 1, 2.5, 5, 7.5, 10]},
#              return_train_score=True, verbose=3)
# [CV 1/4] END ...svc__C=0.75;, score=(train=0.561, test=0.192) total time=  23.7s
# [CV 3/4] END ......svc__C=1;, score=(train=0.647, test=0.244) total time=  23.9s
# [CV 1/4] END ......svc__C=5;, score=(train=0.979, test=0.196) total time=  20.1s
# [CV 2/4] END ......svc__C=5;, score=(train=0.979, test=0.200) total time=  21.7s
# [CV 2/4] END ....svc__C=7.5;, score=(train=0.988, test=0.208) total time=  17.7s
# [CV 2/4] END .....svc__C=10;, score=(train=0.992, test=0.192) total time=  25.7s
# [CV 3/4] END ...svc__C=0.75;, score=(train=0.556, test=0.200) total time=  22.9s
# [CV 3/4] END ......svc__C=1;, score=(train=0.651, test=0.224) total time=  21.0s
# [CV 2/4] END ....svc__C=2.5;, score=(train=0.908, test=0.204) total time=  29.3s
# [CV 2/4] END ......svc__C=5;, score=(train=0.973, test=0.180) total time=  27.3s
# [CV 2/4] END ....svc__C=7.5;, score=(train=0.985, test=0.184) total time=  22.9s
# [CV 1/4] END .....svc__C=10;, score=(train=0.992, test=0.232) total time=  19.4s
# [CV 3/4] END ...svc__C=0.75;, score=(train=0.529, test=0.236) total time=  18.8s
# [CV 1/4] END ......svc__C=1;, score=(train=0.668, test=0.208) total time=  14.5s
# [CV 1/4] END ....svc__C=2.5;, score=(train=0.913, test=0.208) total time=  18.4s
# [CV 4/4] END ....svc__C=2.5;, score=(train=0.903, test=0.204) total time=  21.5s
# [CV 3/4] END ......svc__C=5;, score=(train=0.965, test=0.248) total time=  22.8s
# [CV 3/4] END ....svc__C=7.5;, score=(train=0.987, test=0.240) total time=  25.9s
# [CV 4/4] END .....svc__C=10;, score=(train=0.992, test=0.196) total time=  20.3s
# [CV 4/4] END ...svc__C=0.75;, score=(train=0.537, test=0.244) total time=  19.9s
# [CV 1/4] END ......svc__C=1;, score=(train=0.667, test=0.224) total time=  28.6s
# [CV 3/4] END ....svc__C=2.5;, score=(train=0.889, test=0.192) total time=  27.1s
# [CV 3/4] END ......svc__C=5;, score=(train=0.976, test=0.168) total time=  18.1s
# [CV 1/4] END ....svc__C=7.5;, score=(train=0.985, test=0.244) total time=  26.1s
# [CV 2/4] END .....svc__C=10;, score=(train=0.993, test=0.192) total time=  23.4s
# [CV 2/4] END ...svc__C=0.75;, score=(train=0.571, test=0.224) total time=  24.7s
# [CV 4/4] END ......svc__C=1;, score=(train=0.673, test=0.188) total time=  20.7s
# [CV 2/4] END ....svc__C=2.5;, score=(train=0.892, test=0.216) total time=  27.2s
# [CV 1/4] END ....svc__C=7.5;, score=(train=0.991, test=0.212) total time=  21.9s
# [CV 4/4] END ....svc__C=7.5;, score=(train=0.987, test=0.184) total time=  20.0s
# [CV 3/4] END .....svc__C=10;, score=(train=0.995, test=0.252) total time=  18.4s
# [CV 2/4] END ...svc__C=0.75;, score=(train=0.559, test=0.212) total time=  20.2s
# [CV 2/4] END ......svc__C=1;, score=(train=0.657, test=0.212) total time=  24.9s
# [CV 1/4] END ....svc__C=2.5;, score=(train=0.913, test=0.252) total time=  23.1s
# [CV 1/4] END ......svc__C=5;, score=(train=0.977, test=0.244) total time=  29.9s
# [CV 3/4] END ....svc__C=7.5;, score=(train=0.991, test=0.148) total time=  26.6s
# [CV 3/4] END .....svc__C=10;, score=(train=0.995, test=0.148) total time=  24.3s
# [CV 4/4] END ...svc__C=0.75;, score=(train=0.563, test=0.192) total time=  21.4s
# [CV 2/4] END ......svc__C=1;, score=(train=0.661, test=0.248) total time=  24.5s
# [CV 3/4] END ....svc__C=2.5;, score=(train=0.892, test=0.256) total time=  27.2s
# [CV 4/4] END ......svc__C=5;, score=(train=0.973, test=0.196) total time=  23.8s
# [CV 1/4] END .....svc__C=10;, score=(train=0.997, test=0.208) total time=  25.5s
# [CV 1/4] END ...svc__C=0.75;, score=(train=0.551, test=0.240) total time=  23.1s
# [CV 4/4] END ......svc__C=1;, score=(train=0.657, test=0.240) total time=  25.4s
# [CV 4/4] END ....svc__C=2.5;, score=(train=0.911, test=0.236) total time=  23.9s
# [CV 4/4] END ......svc__C=5;, score=(train=0.976, test=0.228) total time=  23.3s
# [CV 4/4] END ....svc__C=7.5;, score=(train=0.987, test=0.212) total time=  26.5s
# [CV 4/4] END .....svc__C=10;, score=(train=0.995, test=0.216) total time=  25.8s

# %%
# Collect results in a DataFrame
results_svc = pd.DataFrame(gridsearch_svc.cv_results_)

# Print a few interesting columns
cols = ['mean_test_score', 'std_test_score', 'mean_train_score', 'std_train_score', 'param_svc__C']
sorted_svc = results_svc[cols].sort_values('mean_test_score', ascending=False)
sorted_svc.head(10)
# Out:
#    mean_test_score  std_test_score  mean_train_score  std_train_score  \
# 1            0.225        0.009950          0.658000         0.005696
# 0            0.224        0.018547          0.550667         0.008219
# 2            0.221        0.024062          0.905333         0.009428
# 3            0.205        0.031796          0.975667         0.001453
# 5            0.197        0.031670          0.993667         0.001106
# 4            0.197        0.035369          0.987000         0.002186
#
#    param_svc__C
# 1          1.00
# 0          0.75
# 2          2.50
# 3          5.00
# 5         10.00
# 4          7.50

# %% [markdown]
# Compute accuracy of support vector machine classifier on test dataset

# %%
# get best parameter from result of grid search
C = sorted_svc.iloc[0]['param_svc__C']

# set parameter in pipeline
pipe_svc.set_params(svc__C=C)

# fit the model
pipe_svc.fit(X_train, y_train)

# compute accuracy on test dataset
acc_test_svc = pipe_svc.score(X_test, y_test)
acc_test_svc
# Out:
# 0.27601456815816855

# %% [markdown]
# ## Multilayer perceptron classifier
#
# Build a MLP classifier with the defaults and early stopping.

# %%
# create neural network
mlp = MLPClassifier(
    random_state=0,
    early_stopping=True, n_iter_no_change=5, tol=0.01,
    verbose=False
)

pipe_mlp = Pipeline([
    ('scaler', StandardScaler()), # More accurate with standardization
    #('scaler', None), # Better performance (faster) without standardization
    ('mlp', mlp)
])

# %% [markdown]
# Optimize the model's parameters using grid search

# %%
# %%time
from sklearn.model_selection import GridSearchCV

# Create cross-validation object
grid_mlp = {
    'mlp__solver': ['lbfgs', 'sgd'],
    'mlp__hidden_layer_sizes': [(288, 72), (144, 72), (288, 144), 72, 144, 288],
    'mlp__activation': ['relu'],
    'mlp__alpha': [0.0001, 0.00001]
}
# create grid search with cross validation
gridsearch_mlp = GridSearchCV(pipe_mlp, grid_mlp, cv=2, return_train_score=True, verbose=1, n_jobs=4)

# Get a smaller random sample for tuning the parameter
NUM_SAMPLES = 1000
idx = random.sample(range(len(X_train)-1), NUM_SAMPLES)
X_rnd = X_train[idx]
y_rnd = y_train[idx]

# Fit estimator
gridsearch_mlp.fit(X_rnd, y_rnd)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# /home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 24 fits failed out of a total of 48.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/pipeline.py", line 660, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 754, in fit
#     return self._fit(X, y, incremental=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 476, in _fit
#     self._fit_stochastic(
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 660, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 708, in _update_no_improvement_count
#     val_score = self._score(X_val, y_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1189, in _score
#     return super()._score_with_function(X, y, score_function=accuracy_score)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 769, in _score_with_function
#     if np.isnan(y_pred).any() or np.isinf(y_pred).any():
#        ^^^^^^^^^^^^^^^^
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the test scores are non-finite: [0.162   nan 0.158   nan 0.158   nan 0.162   nan 0.158   nan 0.162   nan
#  0.162   nan 0.161   nan 0.157   nan 0.164   nan 0.159   nan 0.162   nan]
#   warnings.warn(
# /home/atroncos/workspace/oa_venv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the train scores are non-finite: [ 1. nan  1. nan  1. nan  1. nan  1. nan  1. nan  1. nan  1. nan  1. nan
#   1. nan  1. nan  1. nan]
#   warnings.warn(
# CPU times: user 9min 30s, sys: 664 ms, total: 9min 31s
# Wall time: 6min 23s
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('mlp',
#                                         MLPClassifier(early_stopping=True,
#                                                       n_iter_no_change=5,
#                                                       random_state=0,
#                                                       tol=0.01))]),
#              n_jobs=4,
#              param_grid={'mlp__activation': ['relu'],
#                          'mlp__alpha': [0.0001, 1e-05],
#                          'mlp__hidden_layer_sizes': [(288, 72), (144, 72),
#                                                      (288, 144), 72, 144, 288],
#                          'mlp__solver': ['lbfgs', 'sgd']},
#              return_train_score=True, verbose=1)

# %%
# Collect results in a DataFrame
results_mlp = pd.DataFrame(gridsearch_mlp.cv_results_)

# Print a few interesting columns
cols = ['mean_test_score', 'std_test_score', 'mean_train_score', 'std_train_score', 
        'param_mlp__solver', 'param_mlp__hidden_layer_sizes', 'param_mlp__activation', 'param_mlp__alpha']
sorted_mlp = results_mlp[cols].sort_values('mean_test_score', ascending=False)
sorted_mlp.head(10)
# Out:
#     mean_test_score  std_test_score  mean_train_score  std_train_score  \
# 18            0.164           0.016               1.0              0.0
# 0             0.162           0.006               1.0              0.0
# 10            0.162           0.026               1.0              0.0
# 22            0.162           0.026               1.0              0.0
# 12            0.162           0.006               1.0              0.0
# 6             0.162           0.014               1.0              0.0
# 14            0.161           0.001               1.0              0.0
# 20            0.159           0.007               1.0              0.0
# 4             0.158           0.002               1.0              0.0
# 2             0.158           0.004               1.0              0.0
#
#    param_mlp__solver param_mlp__hidden_layer_sizes param_mlp__activation  \
# 18             lbfgs                            72                  relu
# 0              lbfgs                     (288, 72)                  relu
# 10             lbfgs                           288                  relu
# 22             lbfgs                           288                  relu
# 12             lbfgs                     (288, 72)                  relu
# 6              lbfgs                            72                  relu
# 14             lbfgs                     (144, 72)                  relu
# 20             lbfgs                           144                  relu
# 4              lbfgs                    (288, 144)                  relu
# 2              lbfgs                     (144, 72)                  relu
#
#     param_mlp__alpha
# 18           0.00001
# 0            0.00010
# 10           0.00010
# 22           0.00001
# 12           0.00001
# 6            0.00010
# 14           0.00001
# 20           0.00001
# 4            0.00010
# 2            0.00010

# %%
# get best parameters from result of grid search
param_mlp__solver = sorted_mlp.iloc[0]['param_mlp__solver']
param_mlp__hidden_layer_sizes = sorted_mlp.iloc[0]['param_mlp__hidden_layer_sizes']
param_mlp__activation = sorted_mlp.iloc[0]['param_mlp__activation']
param_mlp__alpha = sorted_mlp.iloc[0]['param_mlp__alpha']

# set parameters in mlp classifier pipeline
pipe_mlp.set_params(mlp__solver=param_mlp__solver)
pipe_mlp.set_params(mlp__hidden_layer_sizes=param_mlp__hidden_layer_sizes)
pipe_mlp.set_params(mlp__activation=param_mlp__activation)
pipe_mlp.set_params(mlp__alpha=param_mlp__alpha)
pipe_mlp.set_params(mlp__max_iter=400)  # default is 200

# fit the model
pipe_mlp.fit(X_train, y_train)

# compute accuracy on test dataset
acc_test_mlp = pipe_mlp.score(X_test, y_test)

# %%
acc_test_mlp
# Out:
# 0.19302809573361082
